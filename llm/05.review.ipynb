# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.2:1b",
    temperature=0,
)

# %% [markdown]
# ## 음식 이름 찾기

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

food_template = PromptTemplate(
    template='''What is one of the most popular food in {country}? Please return the name of the food only''',
    input_variables=['country']
)

food_chain = food_template | llm | StrOutputParser()

# %%
food_chain.invoke({'country': 'South Korea'})
# Out:
# 'Bibimbap.'

# %% [markdown]
# ## 레시피 찾긹

# %%
from langchain_core.prompts import ChatPromptTemplate

recipe_prompt = ChatPromptTemplate.from_messages([
    ('system', 'Provide the recipe of the food that the user wants. Please return the recipe only as a numbered list.'),
    ('human', 'Can you give me the recipe for making {food}?')
])

recipe_chain = recipe_prompt | llm | StrOutputParser()

# %%
recipe_chain.invoke({'food': 'bibimbap'})
# Out:
# "Here's a traditional Korean recipe for Bibimbap:\n\n**Servings:** 4-6 people\n\n**Ingredients:**\n\n1. **Rice**: 2 cups of white or brown rice, cooked according to package instructions\n2. **Vegetables**:\n\t* 1 cup of bean sprouts\n\t* 1 cup of shredded zucchini\n\t* 1 cup of diced carrots\n\t* 1/2 cup of diced cucumber\n3. **Meat**:\n\t* 1/2 cup of thinly sliced beef ( ribeye or sirloin)\n4. **Eggs**:\n\t* 2 eggs, fried sunny-side up\n5. **Seasonings**:\n\t* 2 tablespoons of soy sauce\n\t* 1 tablespoon of sesame oil\n\t* 1 teaspoon of ground black pepper\n6. **Garnishes**:\n\t* Chopped green onions for garnish\n\t* Sliced red bell peppers for garnish\n\n**Instructions:**\n\n1. Cook the rice according to package instructions.\n2. In a separate pan, heat the sesame oil over medium-high heat. Add the sliced beef and cook until browned, about 3-4 minutes. Set aside.\n3. In another pan, fry an egg sunny-side up.\n4. To assemble the Bibimbap, place a scoop of cooked rice in a bowl. Arrange the vegetables, meat, and fried egg on top of the rice.\n5. Drizzle soy sauce and sesame oil over the ingredients.\n6. Garnish with chopped green onions and sliced red bell peppers.\n7. Serve immediately and enjoy!\n\n**Tips:**\n\n* Use a variety of colorful vegetables to make the dish visually appealing.\n* You can also add other toppings such as diced kimchi or pickled ginger.\n* For a spicy kick, add some gochugaru (Korean chili flakes) to the soy sauce."

# %% [markdown]
# ## 나라 이름으로 유명한 음식 레시피 찾기

# %%
final_chain = {'food': food_chain} | recipe_chain

# %%
final_chain.invoke({'country': 'France'})
# Out:
# "Here is the recipe for traditional French croissants:\n\n**Ingredients:**\n\nFor the dough:\n\n1. 1 cup warm milk (around 105°F to 115°F)\n2. 1/4 cup granulated sugar\n3. 2 teaspoons active dry yeast\n4. 3 cups all-purpose flour\n5. 1 teaspoon salt\n6. 1/4 cup unsalted butter, melted\n\nFor the butter block:\n\n7. 1/2 cup (1 stick) unsalted butter, softened\n8. 1/4 cup granulated sugar\n\n**Instructions:**\n\n**Step 1: Make the dough**\n\n9. In a small bowl, combine warm milk and sugar. Sprinkle yeast over the top and let it sit for 5-10 minutes until frothy.\n10. In a large mixing bowl, whisk together flour, salt, and melted butter.\n11. Add yeast mixture to dry ingredients and mix until a shaggy dough forms.\n12. Knead the dough on a floured surface for 10-12 minutes until smooth and elastic.\n\n**Step 2: Rest the dough**\n\n13. Place the dough in a greased bowl, cover with plastic wrap, and let it rest in a warm place for 1 hour, or until doubled in size.\n14. Punch down the dough and divide into 2-4 equal pieces, depending on desired croissant size.\n\n**Step 3: Make the butter block**\n\n15. On a lightly floured surface, roll out softened butter to a rectangle about 1/2-inch thick.\n16. Brush edges of butter with granulated sugar.\n\n**Step 4: Laminate the dough**\n\n17. Roll out one of the dough pieces to a rectangle about 1/4-inch thick.\n18. Place the butter block on top of the dough, making sure to align edges.\n19. Fold the dough over the butter, like a letter, so that the two rectangles meet in the middle.\n20. Rotate the dough 90 degrees, so the folded edge is facing you.\n21. Roll out the dough to a rectangle about 1/4-inch thick.\n\n**Step 5: Cut and shape croissants**\n\n22. Repeat steps 17-21 with remaining dough pieces.\n23. Cut each rectangle into long, thin triangles.\n24. Roll each triangle into a croissant shape, starting from one of the wide ends.\n25. Place croissants on a parchment-lined baking sheet, leaving about 1 inch of space between each.\n\n**Step 6: Proof and bake**\n\n26. Cover with plastic wrap and let proof in a warm place for 1-2 hours, or until doubled in size.\n27. Preheat oven to 400°F (200°C).\n28. Bake croissants for 15-20 minutes, or until golden brown.\n\n**Step 7: Cool and enjoy**\n\n29. Allow croissants to cool on a wire rack for at least 30 minutes before serving.\n30. Store any leftover croissants in an airtight container for up to 3 days.\n\nNote: Making croissants requires patience, as the dough needs time to rest and rise. Don't be discouraged if your first batch doesn't turn out perfectly – practice makes perfect!"
