# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b")

llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-03-27T13:24:26.471579Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1855245750, 'load_duration': 1615841958, 'prompt_eval_count': 32, 'prompt_eval_duration': 150873250, 'eval_count': 8, 'eval_duration': 78512251, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019d2f77-a98e-74b0-8cd2-683dcbce2d9e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %% [markdown]
# ## invoke 메서드의 파라미터 확인

# %%
llm.invoke(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llm.invoke(0)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:455, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)
#     447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
#     454             self.generate_prompt(
# --> 455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:438, in BaseChatModel._convert_input(self, model_input)
#     433     return ChatPromptValue(messages=convert_to_messages(model_input))
#     434 msg = (
#     435     f"Invalid input type {type(model_input)}. "
#     436     "Must be a PromptValue, str, or list of BaseMessages."
#     437 )
# --> 438 raise ValueError(msg)
#
# ValueError: Invalid input type <class 'int'>. Must be a PromptValue, str, or list of BaseMessages.

# %% [markdown]
# ## PromptTemplate

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate

llm = ChatOllama(model="llama3.2:1b")

prompt_template = PromptTemplate(
    template="What is the capital of {country}?",
    input_variables=["country"],
)
prompt = prompt_template.invoke({"country": "France"})

print(prompt)

llm.invoke(prompt)
# Out:
# text='What is the capital of France?'
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-03-27T13:37:23.192391Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1825652833, 'load_duration': 1520417667, 'prompt_eval_count': 32, 'prompt_eval_duration': 220044458, 'eval_count': 8, 'eval_duration': 75785292, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019d2f83-83c5-79d1-884a-718c66b939aa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %% [markdown]
# ## BaseMessage

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

# few shots > 답변 예
# 대화 이력이 있던 것처럼 LLM을 속여서 답변을 우리가 원하는 형태로 유도
# 복잡한 애플리케이션 구현 시 예시를 주는 것이 정확도를 높이는 방법
message_list = [
    SystemMessage(content="You are a helpful assistant!"),
    HumanMessage(content="What is the capital of France?"),
    AIMessage(content="The capital of France is Paris."),
    HumanMessage(content="What is the capital of Germany?"),
    AIMessage(content="The capital of France is Berlin."),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
]

llm.invoke(message_list)
# Out:
# AIMessage(content='The capital of Germany is Berlin.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-03-28T04:46:55.598302Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2084009125, 'load_duration': 1516745584, 'prompt_eval_count': 62, 'prompt_eval_duration': 482587667, 'eval_count': 8, 'eval_duration': 77244292, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019d32c4-3844-7331-b33c-12bdfe8bba20-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 8, 'total_tokens': 70})

# %% [markdown]
# ## ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant!"),
    ("human", "What is the capital of {country}?"),
])

chat_prompt = chat_prompt_template.invoke({"country": "France"})

print(chat_prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={})]

# %%
chat_prompt.messages
# Out:
# [SystemMessage(content='You are a helpful assistant!', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={})]

# %%
llm.invoke(chat_prompt)
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-03-28T11:37:40.81155Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1868648875, 'load_duration': 1563198000, 'prompt_eval_count': 38, 'prompt_eval_duration': 216381625, 'eval_count': 8, 'eval_duration': 76832500, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019d343c-4759-7981-b495-a0d45873a2c4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 38, 'output_tokens': 8, 'total_tokens': 46})
